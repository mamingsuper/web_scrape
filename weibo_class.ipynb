# %% [markdown]
# ## A Short Guide About Weibo Data Collection
# ### Major Steps
# 🔺 Install necessary packages on your device

# %%
# give colabortary access to your google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
! ls
# list all files within current working folder
# Out:
# gdrive	sample_data

# %%
# enter target folder
# %cd /content/gdrive/MyDrive/Academic/Course/weibo_scrape
# Out:
# /content/gdrive/MyDrive/Academic/Course/weibo_scrape

# %%
# install packages
# !git clone https://github.com/nghuyong/WeiboSpider.git
# Out:
# Cloning into 'WeiboSpider'...
# remote: Enumerating objects: 553, done.
# remote: Counting objects: 100% (234/234), done.
# remote: Compressing objects: 100% (110/110), done.
# remote: Total 553 (delta 166), reused 140 (delta 122), pack-reused 319
# Receiving objects: 100% (553/553), 16.02 MiB | 12.51 MiB/s, done.
# Resolving deltas: 100% (305/305), done.

# %%
# enter WeiboSpider folder
# !cd /content/gdrive/MyDrive/Academic/Course/weibo_scrape

# %%
ls
# Out:
# WeiboSpider/  weibo_tool.ipynb

# %%
# install all related packages needed
# !pip install -r WeiboSpider/requirements.txt

# %%
# install scrapy
# !pip install scrapy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.4/286.4 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 15.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.1/247.1 kB 21.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.7/97.7 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 8.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### set cookie, which resembles ID card on that platform
# 1. Open Weibo with Chrome
# 2. Press F12 or rightclick and then inspect
# 3. Find Network, refresh, and then check headers
# 4. copy the cookies and save into cookies.txt

# %% [markdown]
# ### Change scrape settings
# 1. For instance, we want to know how the public discuss digital governance
# 2. Change keywords and time slot for data collection.

# %%
import os
os.chdir('/content/gdrive/MyDrive/Academic/Course/weibo_scrape/WeiboSpider/weibospider')

# %%
# !ls
# Out:
# cookie.txt.gdoc  middlewares.py  pipelines.py  run_spider.py  settings.py  spiders

# %%
# run the spider
# %run run_spider.py tweet_by_keyword
# Out:
# INFO:scrapy.utils.log:Scrapy 2.11.0 started (bot: spider)
# 2024-02-07 04:23:10 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: spider)
# INFO:scrapy.utils.log:Versions: lxml 4.9.4.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0], pyOpenSSL 24.0.0 (OpenSSL 3.2.1 30 Jan 2024), cryptography 42.0.2, Platform Linux-6.1.58+-x86_64-with-glibc2.35
# 2024-02-07 04:23:10 [scrapy.utils.log] INFO: Versions: lxml 4.9.4.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0], pyOpenSSL 24.0.0 (OpenSSL 3.2.1 30 Jan 2024), cryptography 42.0.2, Platform Linux-6.1.58+-x86_64-with-glibc2.35
# INFO:scrapy.addons:Enabled addons:
# []
# 2024-02-07 04:23:10 [scrapy.addons] INFO: Enabled addons:
# []
# ...

# %%
import pandas as pd
from pandas import json_normalize
import json

file_path = '/content/gdrive/MyDrive/Academic/Course/weibo_scrape/WeiboSpider/output/tweet_spider_by_keyword_20240207042334.jsonl'

data = []
with open(file_path, 'r') as f:
    for line in f:
        data.append(json.loads(line))

df = json_normalize(data, sep='_')

# %%
df.head(3)
# Out:
#                 _id    mblogid           created_at  geo ip_location  \
# 0  4997123436973742  NEKCHtgbI  2024-02-03 00:15:32  NaN      发布于 浙江
# 1  4997243218428729  NENJTzmHf  2024-02-03 08:11:30  NaN        None
# 2  4997257529135216  NEO6YCkuc  2024-02-03 09:08:22  NaN      发布于 河南
#
#    reposts_count  comments_count  attitudes_count             source  \
# 0              0               0                0        OPPO随光而变R17
# 1              1               1                1              微博网页版
# 2              0               0                0  iPhone 12 Pro Max
#
#                                              content  ... user_mbtype  \
# 0  2024年：pebo集团是正规公司，以按照正规企业程序公布本集团微博新闻动态，为国家法律法规...  ...          12
# 1  提高智治效能 护航百姓安全#网络中国年##千岛湖年味# \n　　岁末年初，为保障市容秩序，维...  ...           0
# 2  我投给了“不断追求技术创新”,“抓住数字化、移动化和智能化机会”,“把握时代脉搏”~扎克伯格...  ...          12
#
#    user_verified_type        retweet_id  video geo_type geo_coordinates  \
# ...
